# %%
import pytest
from spflows.data.gecko.gecko_datasets import CoinGeckoDataset
from spflows.data.gecko.gecko_metadata import AllCoinsMetadata,CoinMetadata
from spflows.data.gecko.gecko_utils import get_dataframe_with_freq_bitcoin,get_dataframe_with_freq_from_bitcoin
from spflows.data.gecko.gecko_requests import (
    get_key
)

# %%
date_string="2024-12-18"
coingecko_key = get_key()
all_coins_metadata = AllCoinsMetadata(date_string=date_string,coingecko_key=coingecko_key)
all_coins_metadata.load_existing_timeseries()


coins_not_bitcoin = [coin for coin in all_coins_metadata.df_time_series.keys() if coin != "bitcoin"]
df = all_coins_metadata.df_time_series[coins_not_bitcoin[0]]
df_bitcoin = all_coins_metadata.df_time_series["bitcoin"]
df_bitcoin_freq = get_dataframe_with_freq_bitcoin(df_bitcoin)
df_freq = get_dataframe_with_freq_from_bitcoin(df,df_bitcoin_freq)

dataset = CoinGeckoDataset(coin_id=coins_not_bitcoin[0],df_freq=df_freq,df_bitcoin_freq=df_bitcoin_freq)
# Out:
# 100%|██████████| 3049/3049 [00:03<00:00, 869.25it/s]
# Loaded 926 existing time series.

# %%
coins_not_bitcoin
# Out:
# ['twiskers',
#  'dogelon-classic',
#  'wifi',
#  'global-fan-token',
#  'zenoai',
#  'mstr2100',
#  'millenniumclub-coin-new',
#  'ola',
#  'meme-ai-coin',
#  'ponziothecat',
#  'pumlx',
#  'linda-2',
#  'generational-wealth-3',
#  'xen-crypto-pulsechain',
#  'senate',
#  'ethereum',
#  'ripple',
#  'tether',
#  'solana',
#  'binancecoin',
#  'dogecoin',
#  'usd-coin',
#  'staked-ether',
#  'cardano',
#  'tron',
#  'avalanche-2',
#  'qitmeer-network',
#  'adult-playground',
#  'cryptyk',
#  'overnight-dai',
#  'paypal-usd',
#  'lit',
#  'fantom-bridged-wbtc-fantom',
#  'bananacat-sol',
#  'devomon',
#  'gny',
#  'trump-shuffle',
#  'monkeyhaircut',
#  'fortress',
#  'hachiko-inu-meme',
#  'jelli',
#  'inu-token-63736428-0d5c-4281-8038-3e62c35ac278',
#  'iotube-bridged-wnt-iotex',
#  'hammy',
#  'wrapped-eth-world-chain',
#  'pepe-predator',
#  'harambe-ai',
#  'millionaire-2',
#  'asia-coin',
#  'mork-2',
#  'wrapped-doge-universal',
#  'puss',
#  'as-roma-fan-token',
#  'my-defi-pet',
#  'altair',
#  'cswap',
#  'love-hate-inu',
#  'xp',
#  'meditoc',
#  'jojo-2',
#  'taboo-token',
#  'petcoin-2',
#  'miw-musk',
#  'sora-synthetic-usd',
#  'angryslerf',
#  'taggr',
#  'sensi',
#  'cats-do-something',
#  'ondo-us-dollar-yield',
#  'elexium',
#  'smiling-dolphin',
#  'ark-fintech',
#  'yieldeth-sommelier',
#  'maria',
#  'artificial-neural-network',
#  'smolcoin',
#  'pot',
#  'bridged-wrapped-ether-voltage-finance',
#  'linea-bridged-ldo-linea',
#  'baby-neiro-token',
#  'rei-network',
#  'toad-killer',
#  'cz-on-hyperliquid',
#  'neurashi',
#  'kstarnft',
#  'santos-fc-fan-token',
#  'baby-beercoin',
#  'unified-restaked-lst',
#  'alchemist-ai',
#  'rawr',
#  'polygon-hermez-bridged-usdt-x-layer',
#  'wrapped-real-sociedad-kayen',
#  'axe-cap',
#  'bouncing-seals',
#  'mapped-usdt',
#  'pastel',
#  'naws-ai',
#  'ellipsis-x',
#  'vlaunch-2',
#  'cougar-token',
#  'the-blu-arctic-water-comp',
#  'genuine-ai',
#  'dot-is-ded',
#  'aktionariat-fieldoo-ag-tokenized-shares',
#  'only1',
#  'qusd-q-protocol',
#  'mr-yen-japanese-businessman-runes',
#  'mbd-financials',
#  'cuckadoodledoo',
#  'senspark',
#  'b0rder1ess',
#  'horizon-protocol',
#  'foho-coin',
#  'nettensor',
#  '21x',
#  'redacted-gdupi',
#  'lords',
#  'welfy',
#  'ai-com',
#  'chinu-2',
#  'mocossi-planet',
#  'moola-celo-dollars',
#  'oscar-the-octo',
#  'shine-chain',
#  'aria-currency',
#  'extreme',
#  'chikn-fert',
#  'enosys-usdt',
#  'onmax-2',
#  'bpinky',
#  'klap-finance',
#  'uraniumx',
#  'doglibre',
#  'dehive',
#  'chainlink',
#  'wrapped-steth',
#  'shiba-inu',
#  'the-open-network',
#  'wrapped-bitcoin',
#  'sui',
#  'stellar',
#  'polkadot',
#  'hedera-hashgraph',
#  'weth',
#  'bitcoin-cash',
#  'uniswap',
#  'leo-token',
#  'litecoin',
#  'pepe',
#  'hyperliquid',
#  'near',
#  'wrapped-eeth',
#  'aptos',
#  'ethena-usde',
#  'bitget-token',
#  'internet-computer',
#  'usds',
#  'aave',
#  'crypto-com-chain',
#  'ethereum-classic',
#  'polygon-ecosystem-token',
#  'vechain',
#  'fetch-ai',
#  'bittensor',
#  'mantra-dao',
#  'mantle',
#  'arbitrum',
#  'whitebit',
#  'filecoin',
#  'dai',
#  'kaspa',
#  'ethena',
#  'fantom',
#  'algorand',
#  'blockstack',
#  'cosmos',
#  'optimism',
#  'okb',
#  'immutable-x',
#  'celestia',
#  'ondo-finance',
#  'virtual-protocol',
#  'injective-protocol',
#  'bonk',
#  'theta-token',
#  'dogwifcoin',
#  'pudgy-penguins',
#  'the-graph',
#  'binance-peg-weth',
#  'coinbase-wrapped-btc',
#  'thorchain',
#  'sei-network',
#  'worldcoin-wld',
#  'floki',
#  'rocket-pool-eth',
#  'jasmycoin',
#  'kelp-dao-restaked-eth',
#  'first-digital-usd',
#  'lido-dao',
#  'gala',
#  'mantle-staked-ether',
#  'quant-network',
#  'gatechain-token',
#  'tokenize-xchange',
#  'flare-networks',
#  'beam-2',
#  'lombard-staked-btc',
#  'the-sandbox',
#  'maker',
#  'based-brett',
#  'pyth-network',
#  'fasttoken',
#  'movement',
#  'kaia',
#  'eos',
#  'kucoin-shares',
#  'nexo',
#  'solv-btc',
#  'tezos',
#  'renzo-restaked-eth',
#  'helium',
#  'ethereum-name-service',
#  'raydium',
#  'binance-staked-sol',
#  'jupiter-exchange-solana',
#  'flow',
#  'curve-dao-token',
#  'aioz-network',
#  'dydx-chain',
#  'arweave',
#  'aerodrome-finance',
#  'starknet',
#  'iota',
#  'msol',
#  'bittorrent',
#  'bitcoin-cash-sv',
#  'neo',
#  'elrond-erd-2',
#  'eigenlayer',
#  'xdce-crowd-sale',
#  'coredaoorg',
#  'ether-fi-staked-eth',
#  'axie-infinity',
#  'usual-usd',
#  'matic-network',
#  'mog-coin',
#  'decentraland',
#  'apecoin',
#  'pendle',
#  'solv-protocol-solvbtc-bbn',
#  'arbitrum-bridged-wbtc-arbitrum-one',
#  'peanut-the-squirrel',
#  'chiliz',
#  'conflux-token',
#  'jupiter-staked-sol',
#  'mina-protocol',
#  'l2-standard-bridged-weth-base',
#  'ronin',
#  'fartcoin',
#  'wormhole',
#  'popcat',
#  'arbitrum-bridged-weth-arbitrum-one',
#  'pancakeswap-token',
#  'havven',
#  'jito-governance-token',
#  'akash-network',
#  'compound-governance-token',
#  'zcash',
#  'superfarm',
#  'dydx',
#  'ai16z',
#  'usdd',
#  'ecash',
#  'binance-peg-dogecoin',
#  'dog-go-to-the-moon-rune',
#  'zksync',
#  'notcoin',
#  'amp-token',
#  'chex-token',
#  'axelar',
#  'gnosis',
#  'layerzero',
#  'ether-fi-staked-btc',
#  'mantle-restaked-eth',
#  'coinbase-wrapped-staked-eth',
#  'frax',
#  'tether-gold',
#  'reserve-rights-token',
#  'grass',
#  'terra-luna',
#  'oasis-network',
#  'turbo',
#  'ordinals',
#  'echelon-prime',
#  'spx6900',
#  'blur',
#  'baby-doge-coin',
#  'super-oeth',
#  '1inch',
#  'cat-in-a-dogs-world',
#  'goatseus-maximus',
#  'arkham',
#  'safe',
#  'bitcoin-avalanche-bridged-btc-b',
#  'agentfun-ai',
#  'frax-ether',
#  'beldex',
#  'pumpbtc',
#  'apenft',
#  'polygon-pos-bridged-weth-polygon-pos',
#  'nervos-network',
#  'susds',
#  'kusama',
#  'pax-gold',
#  'ether-fi',
#  'gigachad-2',
#  'neiro-3',
#  'kava',
#  'vana',
#  'livepeer',
#  'trust-wallet-token',
#  'true-usd',
#  'telcoin',
#  'creditcoin-2',
#  'astar',
#  'stader-ethx',
#  'sweth',
#  'dash',
#  'book-of-meme',
#  'qubic-network',
#  'tbtc',
#  'holotoken',
#  'theta-fuel',
#  'usual',
#  'enjincoin',
#  'woo-network',
#  'zilliqa',
#  'dexe',
#  'io',
#  'morpho',
#  'verus-coin',
#  'snek',
#  '0x',
#  'metars-genesis',
#  'quantixai',
#  'convex-finance',
#  'staked-frax-ether',
#  'aethir',
#  'usdb',
#  'hashnote-usyc',
#  'stepn',
#  'wemix-token',
#  'benqi-liquid-staked-avax',
#  'sats-ordinals',
#  'ethereum-pow-iou',
#  'bridged-usdc-polygon-pos-bridge',
#  'celo',
#  'just',
#  'iotex',
#  'l2-standard-bridged-weth-blast',
#  'act-i-the-ai-prophecy',
#  'ankr',
#  'liquid-staked-ethereum',
#  'memecoin-2',
#  'origintrail',
#  'golem',
#  'magic-eden',
#  'aevo-exchange',
#  'earth-2-essence',
#  'pooh',
#  'solmix',
#  'buddy-3',
#  'phiat-protocol',
#  'utopia',
#  'venture-coin-2',
#  'party',
#  'renzo-restaked-eth-fuse',
#  'chewyswap',
#  'little-angry-bunny-v2',
#  'rapids',
#  'pulsara',
#  'wrapped-thunder-token',
#  'staked-ogn',
#  'babysnek',
#  'bluzelle',
#  'meme-network',
#  'monkas',
#  'vertical-ai',
#  'barkcoin',
#  'vite-dao',
#  'riko',
#  'rebel-cars',
#  'avian-network',
#  'woofwork-io',
#  'pepe-uwu',
#  'mox-studio',
#  'betterbelong',
#  'solland',
#  'judgment-ai',
#  'pooltogether',
#  'envision-2',
#  'trestle',
#  'kima',
#  'community-business-token',
#  'zulu-network',
#  'fuku',
#  'defi-shopping-stake',
#  'bridged-usdc-world-chain',
#  'chill-guy-s-friend',
#  'ariva',
#  'steakhouse-eura-base-morpho-vault',
#  'drift-token',
#  'business-coin',
#  'size-2',
#  'ibc-index',
#  'bitmex-token',
#  'felix-2',
#  'lto-network',
#  'hedgy-the-hedgehog',
#  'aave-gusd',
#  'achmed-heart-and-sol',
#  'neroboss',
#  'mode',
#  'futurocoin',
#  'port-ai',
#  'lucha',
#  'polar-inu',
#  'dragon-s-quick',
#  'anokas-network',
#  'caroline',
#  'louie-the-raccoon',
#  'shibonk',
#  '42-coin',
#  'department-of-government-efficiency-5',
#  'polygon-hermez-bridged-usdc-x-layer',
#  '69420',
#  'lost-world',
#  'teh-epik-duck',
#  'sail-2',
#  'starecat',
#  'layerzero-bridged-usdt-aptos',
#  'intern',
#  'meth-protocol',
#  'tonex',
#  'holi',
#  'zebi',
#  'litecoin-mascot',
#  'ghislaine-network',
#  'myso-token',
#  'tron-bsc',
#  'indigg',
#  'lumi-to-da-moon',
#  'coinforge',
#  'overpowered',
#  'zik-token',
#  'bosagora',
#  'diabase',
#  'metatime-coin',
#  'axondao-governance-token',
#  'artificial-general-intelligence',
#  'linpuss',
#  'indigo-dao-governance-token',
#  'reality-vr',
#  'booshi',
#  'smardex',
#  'dlc-link-dlcbtc',
#  'jogeco-dog',
#  'shibabitcoin-2',
#  'hmx',
#  'autobahn-network',
#  'redecoin',
#  'ben-2',
#  'fanfury',
#  'wrapped-rss3',
#  'omni-2',
#  'ernie',
#  'wrapped-ckb',
#  'butter',
#  'fluffington',
#  'achi-inu',
#  'kanga-exchange',
#  'doginme',
#  'tron-beer',
#  'chefdotfun',
#  'bifrost-voucher-manta',
#  'edufex',
#  'rizon',
#  'sage-market',
#  'scribes',
#  'i-like-it-stable-dao',
#  'evereth',
#  'force-protocol',
#  'museum-of-influencers',
#  'com-ordinals',
#  'peanut-s-best-friend',
#  'bybit-staked-sol',
#  'radx-ai',
#  'holygrails-io',
#  'tradfi-bro',
#  'selfiesteve',
#  'starslax',
#  'blackcoin',
#  'x-game',
#  'olyn-by-virtuals',
#  'bridged-wrapped-bitcoin-manta-pacific',
#  'tokocrypto',
#  'believe-in-something-2',
#  'compound-basic-attention-token',
#  'ipor',
#  'x7r',
#  'ccb',
#  'hongkongdao',
#  'jack',
#  'solidus-aitech',
#  'pepe-black',
#  'monkey-puppet-2',
#  'wrapped-dfi',
#  'y2k-2',
#  'mimatic',
#  'battlefly',
#  'elucks',
#  'sunned',
#  'dora-factory-2',
#  'doge',
#  'etherfuse-eurob',
#  'chompcoin',
#  'wrapped-eth-taiko',
#  'half-of-pepe',
#  'kortana',
#  'voidz',
#  'saitachain-coin-2',
#  'aave-snx-v1',
#  'm2-global-wealth-limited-mmx',
#  'kwantxbt',
#  'nym',
#  'guzzler',
#  'castello-coin',
#  'r-games',
#  'sindi',
#  '3a-lending-protocol',
#  'aldrin',
#  'puppacoin',
#  'dechat',
#  'jc-coin',
#  'kapital-dao',
#  'terra-luna-2',
#  'octaplex-network',
#  'wicked',
#  'bullperks',
#  'super-trump',
#  'trendingtool-io',
#  'bitcoin-wizard-mascot',
#  'creo-engine',
#  'solidlydex',
#  'metaderby-hoof',
#  'xplq_astrovault',
#  'reward',
#  'harrypotterwifhatmyrowynn',
#  'jpeg-d-2',
#  'paca-ai',
#  'justice-for-honey',
#  'etheism',
#  'meverse',
#  'haroldcoin',
#  'beam',
#  'bnb-cat',
#  'aelf',
#  'coinex-token',
#  'baoeth-eth-stablepool',
#  'gyoza',
#  'chadgpt',
#  'silver-token-xagx',
#  'polkarare',
#  'pi-network-iou',
#  'memeetf',
#  'venus-usdc',
#  'clubmoon',
#  'thorwallet',
#  'sdrive-app',
#  'aurora-dao',
#  'merlins-seal-usdc',
#  'gagarin',
#  'creamy',
#  'dtng',
#  'creat-or',
#  'compx-xusd',
#  'futurespl',
#  'checkdot',
#  'pacific',
#  'paratoken-2',
#  'djenn',
#  'bbs-network',
#  'tipja',
#  'ufc-fan-token',
#  'hyme',
#  'terrier',
#  'iagent-protocol',
#  'ngatiger',
#  'as-monaco-fan-token',
#  'universal-health-token',
#  'zora-bridged-weth-zora-network',
#  'infinity-skies',
#  'polygen',
#  'based-turbo',
#  'phantasma',
#  'silva-token',
#  'wagie-2',
#  'zunami-governance-token',
#  'baby-myro',
#  'osmosis-allusdt',
#  'blocsport-one',
#  'spike',
#  'aave-amm-wbtc',
#  'dark-frontiers',
#  'croak_on_linea',
#  'jable',
#  'donaswap',
#  'odem',
#  'satoshai',
#  'metazoomee',
#  'suku',
#  'willy',
#  'goldverse-game-token',
#  'life-crypto',
#  'noahswap',
#  'cronk',
#  'kilt-protocol',
#  'iostoken',
#  'taovm',
#  'synatra-staked-sol',
#  'vault-terminal',
#  'culture-of-solana-token',
#  'decentralization-obligatory-practicality-essential',
#  'dastra-network',
#  'bridged-wrapped-steth-axelar',
#  'curveswap',
#  'metapuss',
#  'long-eth',
#  'shoefy',
#  'deplan',
#  'contract-dev-ai',
#  'cyborgism',
#  'gocharge-tech',
#  'sonicwifhat',
#  'mochi-market',
#  'nfinityai',
#  'victory-gem',
#  'matsuri-shiba-inu',
#  'usdc-rainbow-bridge',
#  'xborg',
#  'ketamine',
#  'note',
#  'cobak-token',
#  'insane-labz',
#  'rinia-inu',
#  'bridged-mantra-hashport',
#  'crochet-world',
#  'dystoworld-ai',
#  'aeusd',
#  'iron-finance',
#  'retard-coin',
#  'bnb48-club-token',
#  'frank',
#  'steakd',
#  'demi',
#  'fibos',
#  'rainbow-bridged-wbtc-near-protocol',
#  'the-essential-coin',
#  'sir',
#  'nigi',
#  'alien-worlds',
#  'renzo-restaked-sol',
#  'safemuun',
#  'gold-4',
#  'souiland',
#  'pokkycat',
#  'foom',
#  'solcard',
#  'catwifmelon',
#  'ifarm',
#  'ai9000',
#  'peacepal-ai',
#  'ilcoin',
#  'ihf-smart-debase-token',
#  'doggy-needs-friend',
#  'core-id',
#  'sportsology-game',
#  'kuro',
#  'arthera',
#  'metano',
#  'dex-on-crypto',
#  'nomad',
#  'takamaka-green-coin',
#  'qumva-network',
#  'puppet-on-sol',
#  'talahon',
#  'fancy-games',
#  'dogk',
#  'x-ratio-ai',
#  'dogwifouthat',
#  'hefe',
#  'xandeum-sol',
#  'eiob',
#  'dt-inu',
#  'trade-bionic',
#  'hackenai',
#  'lenard',
#  'veno-yield-bearing-eth',
#  'arkadiko-protocol',
#  'contentbox',
#  'rocket-2',
#  'cultel',
#  'crossfi-2',
#  'solong-the-dragon',
#  'ion',
#  'rosecoin',
#  'primexai',
#  'aave-v3-ghst',
#  'shitcoin-on-ton',
#  'gaming-stars-2',
#  'overnight-fi-usd-arbitrum-one',
#  'teddyonheels',
#  'coinsbit-token',
#  'bridged-tether-ton-bridge',
#  'magic-internet-money-linea',
#  'dogecola',
#  'reecoin-2',
#  'dogecast-2',
#  'trufin-staked-matic',
#  'petur-shiff',
#  'crypto-kit',
#  'wagmicoin',
#  'osmosis',
#  'follow-token',
#  'uni-yvault',
#  'phil',
#  'fire-protocol',
#  'dexit-finance',
#  'yooldo',
#  'wrapped-bch-21-co',
#  'tuzki',
#  'tari-world',
#  'griffain',
#  'uforika',
#  'rizz-solana',
#  'circleswap',
#  'game-integrated-ai-coin',
#  'addickted',
#  'nod-cat',
#  'lee',
#  'ginnan-the-cat',
#  'wrapped-btc-wormhole',
#  'cryptoneur-network-foundation',
#  'aastoken',
#  'wonderman-nation',
#  'wombat-exchange',
#  'chad',
#  'bitcoin-name-service-system',
#  'jetcoin',
#  'liquidus',
#  'wrapped-usdr',
#  'ribbit-meme',
#  'generaitiv',
#  'buddha',
#  'nearlend-dao',
#  'hubble',
#  'viberate',
#  'starship-3',
#  'vivex',
#  'wrapped-sport-club-internacional-kayen',
#  'how-did-you-make-it',
#  'hemera',
#  'leoavax',
#  'fleabone',
#  'tatsu',
#  'layerk',
#  'ai-rig-complex',
#  'spheron-network',
#  'nois',
#  'wawa-cat',
#  'bugscoin',
#  'goofy',
#  'gm-ai',
#  'loom-network',
#  'moo-deng',
#  'ethscriptions',
#  'gas-dao',
#  'let-me-do-it-for-you',
#  'viking-token-viki',
#  'linq',
#  'meeds-dao',
#  'outer-ring',
#  'vetme',
#  'aventis-ai',
#  'grok-girl',
#  'taxsolutions-ai',
#  'laika-bridged-wdoge-laika',
#  'porigon',
#  'kleva',
#  'meld-bridged-usdc-meld',
#  'bip1',
#  'lineabank',
#  'sendor',
#  'krampus',
#  'solabrador-2',
#  'houdini-swap',
#  'weniscoin',
#  'age-of-aquarius',
#  'bob-token',
#  'nuance',
#  'cca',
#  'beer-frog',
#  'centaur',
#  'calvaria-doe',
#  'neural-tensor-dynamics',
#  'global-social-chain',
#  'ocada-ai',
#  'peth',
#  'xcusdt',
#  'hmmm',
#  'siaprime-coin',
#  'tdoge',
#  'alibabacoin',
#  'ballz-of-steel',
#  'mackerel-packs-runes',
#  'genbox',
#  'yfdai-finance',
#  'sugar-boy',
#  'games-for-a-living',
#  'agentlayer',
#  'workoutapp',
#  'fjord-foundry',
#  'pepecoin-on-sol',
#  'six-network',
#  'bkokfi',
#  'make-america-healthy-again',
#  'nebulas',
#  'kimchi-finance',
#  'mr-mint',
#  'crypto-royale',
#  'coffee-ai',
#  'bscm',
#  'xtrabytes',
#  'ghffb47yii2rteeyy10op',
#  'first-convicted-raccoon',
#  'carecoin',
#  'biturbo',
#  'suipepe',
#  'astrid-restaked-reth',
#  'ultrapro',
#  'monkey-pox',
#  'amazon-tokenized-stock-defichain',
#  'diamond-boyz-coin',
#  'minerva-wallet',
#  'metaxy',
#  'heavenland-hto',
#  'santa-2',
#  'xakt_astrovault',
#  'aletheia',
#  'flex-usd',
#  'reform-dao',
#  'pepemon-pepeballs',
#  'pokedx',
#  'nomoex-token',
#  'bxh',
#  'dogwifkatana',
#  'le-bleu-elefant',
#  'catscoin-2',
#  'nothing-token',
#  'goeth',
#  'bnb-bank',
#  'unitus-2',
#  'hasbulla-game',
#  'moji',
#  'roaring-kitty-solana',
#  'papyrus-2',
#  'wanchain',
#  'xai-corp',
#  'nfteyez',
#  'wall-street-baby',
#  'major-dog',
#  'metaelfland',
#  'maxwell-the-spinning-cat',
#  'dsun-token',
#  'pumapay',
#  'smoking-chicken-fish',
#  'yesorno',
#  'mask-network',
#  'penjamin-blinkerton',
#  'bark-gas-token',
#  'keep-network',
#  'mikawa-inu-2',
#  'calamari-network',
#  'pungu',
#  'pawswap',
#  'tsubasa-utilitiy-token',
#  'charactbit',
#  'blobs',
#  'eden-2',
#  'landrocker',
#  'metarix',
#  'molly-the-otter',
#  'epik-prime',
#  'echolink-2',
#  'guanciale',
#  'heliswap',
#  'evrynet',
#  'tereon',
#  'duke-inu-token',
#  'skullcoin',
#  'obi-real-estate',
#  'blockcdn',
#  'kaspa-dao',
#  'pawstars',
#  'honorarium',
#  'realis-network',
#  'donkey',
#  'magikal-ai',
#  'dragonking',
#  'binance-peg-ontology',
#  'forest-knight',
#  'usk',
#  'treasure-labs-loot',
#  'element-280',
#  'polychain-monsters']
